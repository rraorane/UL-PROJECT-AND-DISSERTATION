# %%
# 1) Install
# !pip install -q pyngrok streamlit scikit-learn pandas numpy scipy

# 2) Set your real authtoken (paste it between quotes)
from pyngrok import ngrok, conf
NGROK_AUTH_TOKEN = "31GUqx6gmIqfZKLd1Q8IDuxN3Dw_4KcdLaXggLVauybBYZn3d"  # <-- not 'YOUR_AUTHTOKEN'

conf.get_default().auth_token = NGROK_AUTH_TOKEN
ngrok.kill()  # clean old sessions
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 62.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 50.3 MB/s eta 0:00:00

# %%
# 3) Launch Streamlit
# !streamlit run app.py --server.port 8501 &>/tmp/streamlit.log &

# %%
# 4) Open a tunnel to 8501 and print the URL
from pyngrok import ngrok
public_url = ngrok.connect(8501)
print("Public Streamlit URL:", public_url)
# Out:
# Public Streamlit URL: NgrokTunnel: "https://d7f70426c430.ngrok-free.app" -> "http://localhost:8501"

# %%
# !pkill -f "streamlit run" || true
# !streamlit run /content/app.py --server.port 8501 &>/tmp/streamlit.log &
# Out:
# ^C

# %%
from pyngrok import ngrok, conf
conf.get_default().auth_token = "31GUqx6gmIqfZKLd1Q8IDuxN3Dw_4KcdLaXggLVauybBYZn3d"
ngrok.kill()
print("URL:", ngrok.connect(8501))
# Out:
# URL: NgrokTunnel: "https://1bc83e2566ff.ngrok-free.app" -> "http://localhost:8501"
